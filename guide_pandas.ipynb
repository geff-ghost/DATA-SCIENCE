# %%
import pandas as pd

# %%
air_quality = pd.read_csv("data/air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality["ratio_paris_antwerp"] = (air_quality['station_paris'] / air_quality['station_london'])
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                  NaN
# 2019-05-07 03:00:00             1.315789
# 2019-05-07 04:00:00             1.457895
# 2019-05-07 05:00:00             3.150000
# 2019-05-07 06:00:00                  NaN

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london'] * 1.882
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      ratio_paris_antwerp  londo_mg_per_cubic  \
# datetime
# 2019-05-07 02:00:00                  NaN              43.286
# 2019-05-07 03:00:00             1.315789              35.758
# 2019-05-07 04:00:00             1.457895              35.758
# 2019-05-07 05:00:00             3.150000              30.112
# 2019-05-07 06:00:00                  NaN                 NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      ratio_paris_antwerp  london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                  NaN               43.286
# 2019-05-07 03:00:00             1.315789               35.758
# 2019-05-07 04:00:00             1.457895               35.758
# 2019-05-07 05:00:00             3.150000               30.112
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      ratio_paris_antwerp  london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                  NaN               43.286
# 2019-05-07 03:00:00             1.315789               35.758
# 2019-05-07 04:00:00             1.457895               35.758
# 2019-05-07 05:00:00             3.150000               30.112
# 2019-05-07 06:00:00                  NaN                  NaN
# ...                                  ...                  ...
# 2019-06-20 22:00:00                  NaN                  NaN
# 2019-06-20 23:00:00                  NaN                  NaN
# 2019-06-21 00:00:00                  NaN                  NaN
# 2019-06-21 01:00:00                  NaN                  NaN
# 2019-06-21 02:00:00                  NaN                  NaN
#
# [1035 rows x 5 columns]

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "station_antwerp": "BETR801",
        "station_paris": "FR0414",
        "station_london": "London Westminister"
    }
)

# %%
air_quality_renamed.head()
# Out:
#                      BETR801  FR0414  London Westminister  \
# datetime
# 2019-05-07 02:00:00      NaN     NaN                 23.0
# 2019-05-07 03:00:00     50.5    25.0                 19.0
# 2019-05-07 04:00:00     45.0    27.7                 19.0
# 2019-05-07 05:00:00      NaN    50.4                 16.0
# 2019-05-07 06:00:00      NaN    61.9                  NaN
#
#                      ratio_paris_antwerp  london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                  NaN               43.286
# 2019-05-07 03:00:00             1.315789               35.758
# 2019-05-07 04:00:00             1.457895               35.758
# 2019-05-07 05:00:00             3.150000               30.112
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)
air_quality_renamed
# Out:
#                      betr801  fr0414  london westminister  \
# datetime
# 2019-05-07 02:00:00      NaN     NaN                 23.0
# 2019-05-07 03:00:00     50.5    25.0                 19.0
# 2019-05-07 04:00:00     45.0    27.7                 19.0
# 2019-05-07 05:00:00      NaN    50.4                 16.0
# 2019-05-07 06:00:00      NaN    61.9                  NaN
# ...                      ...     ...                  ...
# 2019-06-20 22:00:00      NaN    21.4                  NaN
# 2019-06-20 23:00:00      NaN    24.9                  NaN
# 2019-06-21 00:00:00      NaN    26.5                  NaN
# 2019-06-21 01:00:00      NaN    21.8                  NaN
# 2019-06-21 02:00:00      NaN    20.0                  NaN
#
#                      ratio_paris_antwerp  london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                  NaN               43.286
# 2019-05-07 03:00:00             1.315789               35.758
# 2019-05-07 04:00:00             1.457895               35.758
# 2019-05-07 05:00:00             3.150000               30.112
# 2019-05-07 06:00:00                  NaN                  NaN
# ...                                  ...                  ...
# 2019-06-20 22:00:00                  NaN                  NaN
# 2019-06-20 23:00:00                  NaN                  NaN
# 2019-06-21 00:00:00                  NaN                  NaN
# 2019-06-21 01:00:00                  NaN                  NaN
# 2019-06-21 02:00:00                  NaN                  NaN
#
# [1035 rows x 5 columns]

# %%
air_quality_renamed['london_mg_per_cubic'].describe
# Out:
# <bound method NDFrame.describe of datetime
# 2019-05-07 02:00:00    43.286
# 2019-05-07 03:00:00    35.758
# 2019-05-07 04:00:00    35.758
# 2019-05-07 05:00:00    30.112
# 2019-05-07 06:00:00       NaN
#                         ...
# 2019-06-20 22:00:00       NaN
# 2019-06-20 23:00:00       NaN
# 2019-06-21 00:00:00       NaN
# 2019-06-21 01:00:00       NaN
# 2019-06-21 02:00:00       NaN
# Name: london_mg_per_cubic, Length: 1035, dtype: float64>
