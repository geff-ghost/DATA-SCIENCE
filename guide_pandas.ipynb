# %%
import pandas as pd

# %%
air_quality = pd.read_csv("data/air_quality_no2.csv", index_col=0, parse_dates=True)

# %%
air_quality.head()

# %%
air_quality["ratio_paris_antwerp"] = (air_quality['station_paris'] / air_quality['station_london'])
air_quality.head()

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london'] * 1.882
air_quality.head()

# %%
air_quality.head()

# %%
air_quality

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "station_antwerp": "BETR801",
        "station_paris": "FR0414",
        "station_london": "London Westminister"
    }
)

# %%
air_quality_renamed.head()

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)
air_quality_renamed

# %%
air_quality_renamed['london_mg_per_cubic'].describe

# %% [markdown]
# # How to calculate summary statistics
# # Aggregating statistics
# what is the average of the Titanic passengers?

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic.head()

# %%
titanic["Age"].mean()

# %%
titanic["Age"].min()

# %% [markdown]
# What is the median age and ticket fare price of the Titanic passengers?

# %%
titanic[["Age", "Fare"]].median()

# %%
titanic[["Age", "Fare"]].describe()

# %%
titanic.agg(
    {
        "Age": ["min", "max", "median", "skew"],
        "Fare": ["min", "max", "median", "mean"]
    }
)

# %% [markdown]
# # Aggregating statistics grouped by category
# What is the average age for male versus femal Titanic passengers?

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()

# %%
titanic[["Sex", "Age"]].groupby("Sex").sum()

# %%
titanic.groupby("Sex").mean(numeric_only=True)

# %%
titanic.groupby("Sex")["Age"].mean()

# %% [markdown]
# What is the mean ticket fare price for each of the sex and cabin class combinations?

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()

# %%
titanic.groupby("Pclass")["Pclass"].mean()

# %% [markdown]
# # Count number of records by category
# What is the number of passengers in each of the cabin classes?

# %%
titanic["Pclass"].value_counts()

# %%
titanic.groupby("Pclass")["Sex"].count()

# %%
titanic.groupby(["Pclass", "Sex"])["Sex"].count()

# %%
titanic.groupby("Pclass")["Pclass"].count()
