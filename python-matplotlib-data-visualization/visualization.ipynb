# %% [markdown]
# # Matplotlib: Data Visualization

# %% [markdown]
# ## Introduction

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 2, 4, 6, 8]
y = [0, 4, 16, 36, 64]

fig, ax = plt.subplots()
ax.plot(x, y, marker='o', label="Data Points")

ax.set_title("Basic Components of Matplotlib Figure")
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")

plt.show()

# %% [markdown]
# # Basic Plotting with Pyplot
#
# ## 1. Line Plot
# Line plots are simplest types of charts. The `plot()` function takes two lists: one for x-axis and one for y-axis and connects the points in a linear path.

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ## 2. Pie Charts
# Pie charts show the share of each category in a whole. The `pie()` function takes a list of values and optiona labels to represent each slice of the pie.

# %%
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 30, 20, 10]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# `Explanation:plt.pie(sizes, labels=labele, autopct='%1.1f%%')` creates a pie chart with slice sizes from `sizes, labels` for each slice and `autopct` show percentage values with one decimal place.

# %% [markdown]
# ## 3. Bar Charts
# Bar charts are ideal for comparing quantities across categories. The `bar()` function takes two lists one for `category` labels (x-axis) and one for their corresponding `values` (y-axis).

# %%
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 2, 5]
plt.xlabel('Categories')
plt.ylabel('Values')
plt.bar(categories, values)
plt.show()

# %% [markdown]
# ## 4. Scatter Plots
# Scatter plots are used for displaying individual data points and showing relationship between two variables. The `scatter()` fuction takes two lists like plot(), but it only plots the individual points without connection them

# %%
x = [1, 2, 3, 4, 5]
y = [5, 7, 9, 11, 13]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## 5. Histograms
# Histograms are used to visualize distribution of a dataset. The `hist()` function takes a list or an array of numerical data and divides it into bins

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.show()

# %% [markdown]
# `np.random.randn(1000)`: generates `1000` random numbers from a standard normal distribution

# %% [markdown]
# `plt.hist(data, bins=30)`: creates a histogram of the data with 30 bins(intervals)
